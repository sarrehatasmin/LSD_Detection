# %%
import os
import time
import copy
import torch
import shutil
from torchvision import datasets, transforms, models
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch import nn, optim
import torch.nn.functional as F
from model_utils import (
    combine_datasets,
    split_dataset,
    count_images_in_directory,
    copy_images
)

# %%
# Define transforms for training, validation, and testing
train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), shear=10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

valid_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Paths for the datasets
original_dataset_dir = '/workspace/archive/Lumpy Skin Images Dataset'
combined_dataset_dir = '/workspace/archive/combined_dataset'

# Load the original datasets (Normal and Lumpy Skin)
original_normal_skin_dir = os.path.join(original_dataset_dir, 'Normal Skin')
original_lumpy_skin_dir = os.path.join(original_dataset_dir, 'Lumpy Skin')

# Load the combined datasets (Normal and Lumpy Skin)
combined_normal_skin_dir = os.path.join(combined_dataset_dir, 'Normal Skin')
combined_lumpy_skin_dir = os.path.join(combined_dataset_dir, 'Lumpy Skin')

# Define the original datasets using ImageFolder with transformations for training
original_train_dataset = datasets.ImageFolder(root=original_dataset_dir, transform=train_transforms)
original_valid_dataset = datasets.ImageFolder(root=original_dataset_dir, transform=valid_transforms)
combined_train_dataset = datasets.ImageFolder(root=combined_dataset_dir, transform=train_transforms)
combined_valid_dataset = datasets.ImageFolder(root=combined_dataset_dir, transform=valid_transforms)

# Create DataLoaders for both original and combined datasets
original_train_loader = DataLoader(original_train_dataset, batch_size=32, shuffle=True)
original_valid_loader = DataLoader(original_valid_dataset, batch_size=32, shuffle=False)
combined_train_loader = DataLoader(combined_train_dataset, batch_size=32, shuffle=True)
combined_valid_loader = DataLoader(combined_valid_dataset, batch_size=32, shuffle=False)

# Define test dataset for original and combined datasets separately
original_test_dataset = datasets.ImageFolder(root=original_dataset_dir, transform=valid_transforms)
combined_test_dataset = datasets.ImageFolder(root=combined_dataset_dir, transform=valid_transforms)

# Create DataLoaders for the original and combined test datasets
original_test_loader = DataLoader(original_test_dataset, batch_size=32, shuffle=False)
combined_test_loader = DataLoader(combined_test_dataset, batch_size=32, shuffle=False)

print("Original Dataset (Training):")
print(f"Number of batches: {len(original_train_loader)}")
for images, labels in original_train_loader:
    print(f"Image batch size: {images.size()}")
    break

print("\nCombined Dataset (Training):")
print(f"Number of batches: {len(combined_train_loader)}")
for images, labels in combined_train_loader:
    print(f"Image batch size: {images.size()}")
    break


print("\nOriginal Dataset (Validation):")
print(f"Number of batches: {len(original_valid_loader)}")
for images, labels in original_valid_loader:
    print(f"Image batch size: {images.size()}")
    break

print("\nCombined Dataset (Validation):")
print(f"Number of batches: {len(combined_valid_loader)}")
for images, labels in combined_valid_loader:
    print(f"Image batch size: {images.size()}")
    break

print("\nOriginal Dataset (Test):")
print(f"Number of batches: {len(original_test_loader)}")
for images, labels in original_test_loader:
    print(f"Image batch size: {images.size()}")
    break

print("\nCombined Dataset (Test):")
print(f"Number of batches: {len(combined_test_loader)}")
for images, labels in combined_test_loader:
    print(f"Image batch size: {images.size()}")
    break

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

densenet = models.densenet121(pretrained=True)  

for param in densenet.parameters():
    param.requires_grad = False


class CustomDenseNet(nn.Module):
    def __init__(self, base_model, num_classes):
        super(CustomDenseNet, self).__init__()
        
        self.features = base_model.features
        
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))  
        self.dropout = nn.Dropout(0.15)                      
        self.fc1 = nn.Linear(1024, 1024)                     
        self.relu = nn.ReLU()                                
        self.fc2 = nn.Linear(1024, num_classes)              


    def forward(self, x):
    
        x = self.features(x)  
        
        if isinstance(x, list):  
            x = torch.cat(x, dim=1)

        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        
        return x

# %%
from torchinfo import summary
from torchvision import models

custom_model = CustomDenseNet(densenet, num_classes=2)
custom_model.to(device)
summary(custom_model, input_size=(32, 3, 224, 224))  #
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomDenseNet                           [32, 2]                   --
# ├─Sequential: 1-1                        [32, 1024, 7, 7]          --
# │    └─Conv2d: 2-1                       [32, 64, 112, 112]        (9,408)
# │    └─BatchNorm2d: 2-2                  [32, 64, 112, 112]        (128)
# │    └─ReLU: 2-3                         [32, 64, 112, 112]        --
# │    └─MaxPool2d: 2-4                    [32, 64, 56, 56]          --
# │    └─_DenseBlock: 2-5                  [32, 256, 56, 56]         --
# │    │    └─_DenseLayer: 3-1             [32, 32, 56, 56]          (45,440)
# │    │    └─_DenseLayer: 3-2             [32, 32, 56, 56]          (49,600)
# │    │    └─_DenseLayer: 3-3             [32, 32, 56, 56]          (53,760)
# │    │    └─_DenseLayer: 3-4             [32, 32, 56, 56]          (57,920)
# │    │    └─_DenseLayer: 3-5             [32, 32, 56, 56]          (62,080)
# │    │    └─_DenseLayer: 3-6             [32, 32, 56, 56]          (66,240)
# │    └─_Transition: 2-6                  [32, 128, 28, 28]         --
# │    │    └─BatchNorm2d: 3-7             [32, 256, 56, 56]         (512)
# │    │    └─ReLU: 3-8                    [32, 256, 56, 56]         --
# │    │    └─Conv2d: 3-9                  [32, 128, 56, 56]         (32,768)
# │    │    └─AvgPool2d: 3-10              [32, 128, 28, 28]         --
# │    └─_DenseBlock: 2-7                  [32, 512, 28, 28]         --
# │    │    └─_DenseLayer: 3-11            [32, 32, 28, 28]          (53,760)
# │    │    └─_DenseLayer: 3-12            [32, 32, 28, 28]          (57,920)
# │    │    └─_DenseLayer: 3-13            [32, 32, 28, 28]          (62,080)
# │    │    └─_DenseLayer: 3-14            [32, 32, 28, 28]          (66,240)
# │    │    └─_DenseLayer: 3-15            [32, 32, 28, 28]          (70,400)
# │    │    └─_DenseLayer: 3-16            [32, 32, 28, 28]          (74,560)
# │    │    └─_DenseLayer: 3-17            [32, 32, 28, 28]          (78,720)
# │    │    └─_DenseLayer: 3-18            [32, 32, 28, 28]          (82,880)
# │    │    └─_DenseLayer: 3-19            [32, 32, 28, 28]          (87,040)
# │    │    └─_DenseLayer: 3-20            [32, 32, 28, 28]          (91,200)
# │    │    └─_DenseLayer: 3-21            [32, 32, 28, 28]          (95,360)
# │    │    └─_DenseLayer: 3-22            [32, 32, 28, 28]          (99,520)
# │    └─_Transition: 2-8                  [32, 256, 14, 14]         --
# │    │    └─BatchNorm2d: 3-23            [32, 512, 28, 28]         (1,024)
# │    │    └─ReLU: 3-24                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-25                 [32, 256, 28, 28]         (131,072)
# │    │    └─AvgPool2d: 3-26              [32, 256, 14, 14]         --
# │    └─_DenseBlock: 2-9                  [32, 1024, 14, 14]        --
# │    │    └─_DenseLayer: 3-27            [32, 32, 14, 14]          (70,400)
# │    │    └─_DenseLayer: 3-28            [32, 32, 14, 14]          (74,560)
# │    │    └─_DenseLayer: 3-29            [32, 32, 14, 14]          (78,720)
# │    │    └─_DenseLayer: 3-30            [32, 32, 14, 14]          (82,880)
# │    │    └─_DenseLayer: 3-31            [32, 32, 14, 14]          (87,040)
# │    │    └─_DenseLayer: 3-32            [32, 32, 14, 14]          (91,200)
# │    │    └─_DenseLayer: 3-33            [32, 32, 14, 14]          (95,360)
# │    │    └─_DenseLayer: 3-34            [32, 32, 14, 14]          (99,520)
# │    │    └─_DenseLayer: 3-35            [32, 32, 14, 14]          (103,680)
# │    │    └─_DenseLayer: 3-36            [32, 32, 14, 14]          (107,840)
# │    │    └─_DenseLayer: 3-37            [32, 32, 14, 14]          (112,000)
# │    │    └─_DenseLayer: 3-38            [32, 32, 14, 14]          (116,160)
# │    │    └─_DenseLayer: 3-39            [32, 32, 14, 14]          (120,320)
# │    │    └─_DenseLayer: 3-40            [32, 32, 14, 14]          (124,480)
# │    │    └─_DenseLayer: 3-41            [32, 32, 14, 14]          (128,640)
# │    │    └─_DenseLayer: 3-42            [32, 32, 14, 14]          (132,800)
# │    │    └─_DenseLayer: 3-43            [32, 32, 14, 14]          (136,960)
# │    │    └─_DenseLayer: 3-44            [32, 32, 14, 14]          (141,120)
# │    │    └─_DenseLayer: 3-45            [32, 32, 14, 14]          (145,280)
# │    │    └─_DenseLayer: 3-46            [32, 32, 14, 14]          (149,440)
# │    │    └─_DenseLayer: 3-47            [32, 32, 14, 14]          (153,600)
# │    │    └─_DenseLayer: 3-48            [32, 32, 14, 14]          (157,760)
# │    │    └─_DenseLayer: 3-49            [32, 32, 14, 14]          (161,920)
# │    │    └─_DenseLayer: 3-50            [32, 32, 14, 14]          (166,080)
# │    └─_Transition: 2-10                 [32, 512, 7, 7]           --
# │    │    └─BatchNorm2d: 3-51            [32, 1024, 14, 14]        (2,048)
# │    │    └─ReLU: 3-52                   [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-53                 [32, 512, 14, 14]         (524,288)
# │    │    └─AvgPool2d: 3-54              [32, 512, 7, 7]           --
# │    └─_DenseBlock: 2-11                 [32, 1024, 7, 7]          --
# │    │    └─_DenseLayer: 3-55            [32, 32, 7, 7]            (103,680)
# │    │    └─_DenseLayer: 3-56            [32, 32, 7, 7]            (107,840)
# │    │    └─_DenseLayer: 3-57            [32, 32, 7, 7]            (112,000)
# │    │    └─_DenseLayer: 3-58            [32, 32, 7, 7]            (116,160)
# │    │    └─_DenseLayer: 3-59            [32, 32, 7, 7]            (120,320)
# │    │    └─_DenseLayer: 3-60            [32, 32, 7, 7]            (124,480)
# │    │    └─_DenseLayer: 3-61            [32, 32, 7, 7]            (128,640)
# │    │    └─_DenseLayer: 3-62            [32, 32, 7, 7]            (132,800)
# │    │    └─_DenseLayer: 3-63            [32, 32, 7, 7]            (136,960)
# │    │    └─_DenseLayer: 3-64            [32, 32, 7, 7]            (141,120)
# │    │    └─_DenseLayer: 3-65            [32, 32, 7, 7]            (145,280)
# │    │    └─_DenseLayer: 3-66            [32, 32, 7, 7]            (149,440)
# │    │    └─_DenseLayer: 3-67            [32, 32, 7, 7]            (153,600)
# │    │    └─_DenseLayer: 3-68            [32, 32, 7, 7]            (157,760)
# │    │    └─_DenseLayer: 3-69            [32, 32, 7, 7]            (161,920)
# │    │    └─_DenseLayer: 3-70            [32, 32, 7, 7]            (166,080)
# │    └─BatchNorm2d: 2-12                 [32, 1024, 7, 7]          (2,048)
# ├─AdaptiveAvgPool2d: 1-2                 [32, 1024, 1, 1]          --
# ├─Dropout: 1-3                           [32, 1024]                --
# ├─Linear: 1-4                            [32, 1024]                1,049,600
# ├─ReLU: 1-5                              [32, 1024]                --
# ├─Linear: 1-6                            [32, 2]                   2,050
# ==========================================================================================
# Total params: 8,005,506
# Trainable params: 1,051,650
# Non-trainable params: 6,953,856
# Total mult-adds (G): 90.70
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5777.33
# Params size (MB): 32.02
# Estimated Total Size (MB): 5828.62
# ==========================================================================================

# %%
learning_rate = 1e-4  
batch_size = 32

optimizer = optim.Adam(custom_model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

original_train_loss_history = []
original_train_accuracy_history = []
original_valid_loss_history = []
original_valid_accuracy_history = []

combined_train_loss_history = []
combined_train_accuracy_history = []
combined_valid_loss_history = []
combined_valid_accuracy_history = []

model_dir = "./models1"
os.makedirs(model_dir, exist_ok=True)

def train_phase(train_loader, model, optimizer, criterion, dataset_name="Train"):
    model.train()  
    running_train_loss = 0.0
    correct_train_predictions = 0
    total_train_predictions = 0

    for inputs, labels in train_loader:
    
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item() * inputs.size(0)  
        _, predicted = torch.max(outputs, 1)
        correct_train_predictions += (predicted == labels).sum().item()
        total_train_predictions += labels.size(0)

    train_acc = correct_train_predictions / total_train_predictions
    train_loss = running_train_loss / len(train_loader.dataset)
    
    if dataset_name == "Original":
        original_train_loss_history.append(train_loss)
        original_train_accuracy_history.append(train_acc)
    else:
        combined_train_loss_history.append(train_loss)
        combined_train_accuracy_history.append(train_acc)
    
    print(f"{dataset_name} Phase: Loss: {train_loss:.4f}, Accuracy: {train_acc:.4f}")
    
    return train_loss, train_acc


def validation_phase(valid_loader, model, criterion, dataset_name="Validation"):
    model.eval()  
    running_valid_loss = 0.0
    correct_valid_predictions = 0
    total_valid_predictions = 0

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
        
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_valid_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_valid_predictions += (predicted == labels).sum().item()
            total_valid_predictions += labels.size(0)

    valid_acc = correct_valid_predictions / total_valid_predictions
    valid_loss = running_valid_loss / len(valid_loader.dataset)
    
    if dataset_name == "Original":
        original_valid_loss_history.append(valid_loss)
        original_valid_accuracy_history.append(valid_acc)
    else:
        combined_valid_loss_history.append(valid_loss)
        combined_valid_accuracy_history.append(valid_acc)
    
    print(f"{dataset_name} Phase: Loss: {valid_loss:.4f}, Accuracy: {valid_acc:.4f}")
    
    return valid_loss, valid_acc


def train_model(train_loader, valid_loader, model, optimizer, criterion, epochs=30, patience=5, dataset_name="Original"):
    """
    Main training loop for training the model.
    """
    best_model_wts = copy.deepcopy(model.state_dict())  
    best_val_acc = 0.0
    early_stop_counter = 0

    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs} - Dataset: {dataset_name}")

        start_time = time.time()

        train_loss, train_acc = train_phase(train_loader, model, optimizer, criterion, dataset_name)

        valid_loss, valid_acc = validation_phase(valid_loader, model, criterion, dataset_name)

        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}")
        print(f"Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.4f}")
        
        if valid_acc > best_val_acc:
            print(f"Validation accuracy improved from {best_val_acc:.4f} to {valid_acc:.4f}. Saving model.")
            best_val_acc = valid_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            model_path = os.path.join(model_dir, f"{dataset_name}_model_{epoch + 1:02d}-{valid_acc:.4f}.pth")
            torch.save(model.state_dict(), model_path)
            early_stop_counter = 0 
        else:
            print(f"Validation accuracy did not improve from {best_val_acc:.4f}")
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs.")
            break

        epoch_time = time.time() - start_time
        print(f"Epoch {epoch + 1} completed in {epoch_time:.2f} seconds.")

    model.load_state_dict(best_model_wts)

    return model, best_val_acc

# %%
custom_model, best_val_acc_original = train_model(
    original_train_loader, 
    original_valid_loader, 
    custom_model, 
    optimizer, 
    criterion, 
    dataset_name="Original"
)
# Out:
# Epoch 1/30 - Dataset: Original
# Original Phase: Loss: 0.5100, Accuracy: 0.7528
# Original Phase: Loss: 0.3933, Accuracy: 0.8300
# Train Loss: 0.5100, Train Accuracy: 0.7528
# Validation Loss: 0.3933, Validation Accuracy: 0.8300
# Validation accuracy improved from 0.0000 to 0.8300. Saving model.
# Epoch 1 completed in 7.81 seconds.
#
# Epoch 2/30 - Dataset: Original
# Original Phase: Loss: 0.3536, Accuracy: 0.8594
# Original Phase: Loss: 0.3178, Accuracy: 0.8658
# Train Loss: 0.3536, Train Accuracy: 0.8594
# Validation Loss: 0.3178, Validation Accuracy: 0.8658
# Validation accuracy improved from 0.8300 to 0.8658. Saving model.
# Epoch 2 completed in 9.45 seconds.
#
# Epoch 3/30 - Dataset: Original
# Original Phase: Loss: 0.2917, Accuracy: 0.8860
# Original Phase: Loss: 0.2874, Accuracy: 0.8732
# Train Loss: 0.2917, Train Accuracy: 0.8860
# Validation Loss: 0.2874, Validation Accuracy: 0.8732
# Validation accuracy improved from 0.8658 to 0.8732. Saving model.
# Epoch 3 completed in 7.36 seconds.
#
# Epoch 4/30 - Dataset: Original
# Original Phase: Loss: 0.2653, Accuracy: 0.8971
# Original Phase: Loss: 0.2728, Accuracy: 0.8814
# Train Loss: 0.2653, Train Accuracy: 0.8971
# Validation Loss: 0.2728, Validation Accuracy: 0.8814
# Validation accuracy improved from 0.8732 to 0.8814. Saving model.
# Epoch 4 completed in 8.07 seconds.
#
# Epoch 5/30 - Dataset: Original
# Original Phase: Loss: 0.2599, Accuracy: 0.8989
# Original Phase: Loss: 0.2345, Accuracy: 0.9136
# Train Loss: 0.2599, Train Accuracy: 0.8989
# Validation Loss: 0.2345, Validation Accuracy: 0.9136
# Validation accuracy improved from 0.8814 to 0.9136. Saving model.
# Epoch 5 completed in 7.39 seconds.
#
# Epoch 6/30 - Dataset: Original
# Original Phase: Loss: 0.2644, Accuracy: 0.8915
# Original Phase: Loss: 0.2354, Accuracy: 0.9090
# Train Loss: 0.2644, Train Accuracy: 0.8915
# Validation Loss: 0.2354, Validation Accuracy: 0.9090
# Validation accuracy did not improve from 0.9136
# Epoch 6 completed in 7.28 seconds.
#
# Epoch 7/30 - Dataset: Original
# Original Phase: Loss: 0.2527, Accuracy: 0.8971
# Original Phase: Loss: 0.2084, Accuracy: 0.9311
# Train Loss: 0.2527, Train Accuracy: 0.8971
# Validation Loss: 0.2084, Validation Accuracy: 0.9311
# Validation accuracy improved from 0.9136 to 0.9311. Saving model.
# Epoch 7 completed in 7.34 seconds.
#
# Epoch 8/30 - Dataset: Original
# Original Phase: Loss: 0.2490, Accuracy: 0.9062
# Original Phase: Loss: 0.2036, Accuracy: 0.9292
# Train Loss: 0.2490, Train Accuracy: 0.9062
# Validation Loss: 0.2036, Validation Accuracy: 0.9292
# Validation accuracy did not improve from 0.9311
# Epoch 8 completed in 7.28 seconds.
#
# Epoch 9/30 - Dataset: Original
# Original Phase: Loss: 0.2273, Accuracy: 0.9164
# Original Phase: Loss: 0.2113, Accuracy: 0.9200
# Train Loss: 0.2273, Train Accuracy: 0.9164
# Validation Loss: 0.2113, Validation Accuracy: 0.9200
# Validation accuracy did not improve from 0.9311
# Epoch 9 completed in 7.27 seconds.
#
# Epoch 10/30 - Dataset: Original
# Original Phase: Loss: 0.2214, Accuracy: 0.9127
# Original Phase: Loss: 0.1922, Accuracy: 0.9311
# Train Loss: 0.2214, Train Accuracy: 0.9127
# Validation Loss: 0.1922, Validation Accuracy: 0.9311
# Validation accuracy did not improve from 0.9311
# Epoch 10 completed in 7.28 seconds.
#
# Epoch 11/30 - Dataset: Original
# Original Phase: Loss: 0.2121, Accuracy: 0.9274
# Original Phase: Loss: 0.1955, Accuracy: 0.9274
# Train Loss: 0.2121, Train Accuracy: 0.9274
# Validation Loss: 0.1955, Validation Accuracy: 0.9274
# Validation accuracy did not improve from 0.9311
# Epoch 11 completed in 7.27 seconds.
#
# Epoch 12/30 - Dataset: Original
# Original Phase: Loss: 0.2152, Accuracy: 0.9118
# Original Phase: Loss: 0.1806, Accuracy: 0.9366
# Train Loss: 0.2152, Train Accuracy: 0.9118
# Validation Loss: 0.1806, Validation Accuracy: 0.9366
# Validation accuracy improved from 0.9311 to 0.9366. Saving model.
# Epoch 12 completed in 7.34 seconds.
#
# Epoch 13/30 - Dataset: Original
# Original Phase: Loss: 0.2079, Accuracy: 0.9265
# Original Phase: Loss: 0.1795, Accuracy: 0.9403
# Train Loss: 0.2079, Train Accuracy: 0.9265
# Validation Loss: 0.1795, Validation Accuracy: 0.9403
# Validation accuracy improved from 0.9366 to 0.9403. Saving model.
# Epoch 13 completed in 7.85 seconds.
#
# Epoch 14/30 - Dataset: Original
# Original Phase: Loss: 0.2126, Accuracy: 0.9274
# Original Phase: Loss: 0.1899, Accuracy: 0.9274
# Train Loss: 0.2126, Train Accuracy: 0.9274
# Validation Loss: 0.1899, Validation Accuracy: 0.9274
# Validation accuracy did not improve from 0.9403
# Epoch 14 completed in 7.28 seconds.
#
# Epoch 15/30 - Dataset: Original
# Original Phase: Loss: 0.2022, Accuracy: 0.9191
# Original Phase: Loss: 0.1803, Accuracy: 0.9311
# Train Loss: 0.2022, Train Accuracy: 0.9191
# Validation Loss: 0.1803, Validation Accuracy: 0.9311
# Validation accuracy did not improve from 0.9403
# Epoch 15 completed in 7.29 seconds.
#
# Epoch 16/30 - Dataset: Original
# Original Phase: Loss: 0.1960, Accuracy: 0.9320
# Original Phase: Loss: 0.1664, Accuracy: 0.9403
# Train Loss: 0.1960, Train Accuracy: 0.9320
# Validation Loss: 0.1664, Validation Accuracy: 0.9403
# Validation accuracy did not improve from 0.9403
# Epoch 16 completed in 7.28 seconds.
#
# Epoch 17/30 - Dataset: Original
# Original Phase: Loss: 0.1982, Accuracy: 0.9329
# Original Phase: Loss: 0.1676, Accuracy: 0.9412
# Train Loss: 0.1982, Train Accuracy: 0.9329
# Validation Loss: 0.1676, Validation Accuracy: 0.9412
# Validation accuracy improved from 0.9403 to 0.9412. Saving model.
# Epoch 17 completed in 7.35 seconds.
#
# Epoch 18/30 - Dataset: Original
# Original Phase: Loss: 0.1789, Accuracy: 0.9292
# Original Phase: Loss: 0.1564, Accuracy: 0.9476
# Train Loss: 0.1789, Train Accuracy: 0.9292
# Validation Loss: 0.1564, Validation Accuracy: 0.9476
# Validation accuracy improved from 0.9412 to 0.9476. Saving model.
# Epoch 18 completed in 7.33 seconds.
#
# Epoch 19/30 - Dataset: Original
# Original Phase: Loss: 0.1979, Accuracy: 0.9200
# Original Phase: Loss: 0.1563, Accuracy: 0.9403
# Train Loss: 0.1979, Train Accuracy: 0.9200
# Validation Loss: 0.1563, Validation Accuracy: 0.9403
# Validation accuracy did not improve from 0.9476
# Epoch 19 completed in 7.32 seconds.
#
# Epoch 20/30 - Dataset: Original
# Original Phase: Loss: 0.1960, Accuracy: 0.9256
# Original Phase: Loss: 0.1655, Accuracy: 0.9347
# Train Loss: 0.1960, Train Accuracy: 0.9256
# Validation Loss: 0.1655, Validation Accuracy: 0.9347
# Validation accuracy did not improve from 0.9476
# Epoch 20 completed in 7.29 seconds.
#
# Epoch 21/30 - Dataset: Original
# Original Phase: Loss: 0.1848, Accuracy: 0.9338
# Original Phase: Loss: 0.1563, Accuracy: 0.9439
# Train Loss: 0.1848, Train Accuracy: 0.9338
# Validation Loss: 0.1563, Validation Accuracy: 0.9439
# Validation accuracy did not improve from 0.9476
# Epoch 21 completed in 7.33 seconds.
#
# Epoch 22/30 - Dataset: Original
# Original Phase: Loss: 0.1688, Accuracy: 0.9430
# Original Phase: Loss: 0.1650, Accuracy: 0.9357
# Train Loss: 0.1688, Train Accuracy: 0.9430
# Validation Loss: 0.1650, Validation Accuracy: 0.9357
# Validation accuracy did not improve from 0.9476
# Epoch 22 completed in 7.37 seconds.
#
# Epoch 23/30 - Dataset: Original
# Original Phase: Loss: 0.2024, Accuracy: 0.9246
# Original Phase: Loss: 0.1439, Accuracy: 0.9494
# Train Loss: 0.2024, Train Accuracy: 0.9246
# Validation Loss: 0.1439, Validation Accuracy: 0.9494
# Validation accuracy improved from 0.9476 to 0.9494. Saving model.
# Epoch 23 completed in 7.37 seconds.
#
# Epoch 24/30 - Dataset: Original
# Original Phase: Loss: 0.1766, Accuracy: 0.9338
# Original Phase: Loss: 0.1434, Accuracy: 0.9494
# Train Loss: 0.1766, Train Accuracy: 0.9338
# Validation Loss: 0.1434, Validation Accuracy: 0.9494
# Validation accuracy did not improve from 0.9494
# Epoch 24 completed in 7.28 seconds.
#
# Epoch 25/30 - Dataset: Original
# Original Phase: Loss: 0.1727, Accuracy: 0.9320
# Original Phase: Loss: 0.1399, Accuracy: 0.9485
# Train Loss: 0.1727, Train Accuracy: 0.9320
# Validation Loss: 0.1399, Validation Accuracy: 0.9485
# Validation accuracy did not improve from 0.9494
# Epoch 25 completed in 7.28 seconds.
#
# Epoch 26/30 - Dataset: Original
# Original Phase: Loss: 0.1569, Accuracy: 0.9403
# Original Phase: Loss: 0.1395, Accuracy: 0.9467
# Train Loss: 0.1569, Train Accuracy: 0.9403
# Validation Loss: 0.1395, Validation Accuracy: 0.9467
# Validation accuracy did not improve from 0.9494
# Epoch 26 completed in 7.29 seconds.
#
# Epoch 27/30 - Dataset: Original
# Original Phase: Loss: 0.1650, Accuracy: 0.9357
# Original Phase: Loss: 0.1352, Accuracy: 0.9596
# Train Loss: 0.1650, Train Accuracy: 0.9357
# Validation Loss: 0.1352, Validation Accuracy: 0.9596
# Validation accuracy improved from 0.9494 to 0.9596. Saving model.
# Epoch 27 completed in 7.57 seconds.
#
# Epoch 28/30 - Dataset: Original
# Original Phase: Loss: 0.1760, Accuracy: 0.9347
# Original Phase: Loss: 0.1329, Accuracy: 0.9494
# Train Loss: 0.1760, Train Accuracy: 0.9347
# Validation Loss: 0.1329, Validation Accuracy: 0.9494
# Validation accuracy did not improve from 0.9596
# Epoch 28 completed in 7.29 seconds.
#
# Epoch 29/30 - Dataset: Original
# Original Phase: Loss: 0.1490, Accuracy: 0.9412
# Original Phase: Loss: 0.1552, Accuracy: 0.9357
# Train Loss: 0.1490, Train Accuracy: 0.9412
# Validation Loss: 0.1552, Validation Accuracy: 0.9357
# Validation accuracy did not improve from 0.9596
# Epoch 29 completed in 7.29 seconds.
#
# Epoch 30/30 - Dataset: Original
# Original Phase: Loss: 0.1626, Accuracy: 0.9357
# Original Phase: Loss: 0.1300, Accuracy: 0.9513
# Train Loss: 0.1626, Train Accuracy: 0.9357
# Validation Loss: 0.1300, Validation Accuracy: 0.9513
# Validation accuracy did not improve from 0.9596
# Epoch 30 completed in 7.29 seconds.

# %%
custom_model_combined, best_val_acc_combined = train_model(
    combined_train_loader, 
    combined_valid_loader, 
    custom_model, 
    optimizer, 
    criterion, 
    dataset_name="Combined"
)
# Out:
# Epoch 1/30 - Dataset: Combined
# Combined Phase: Loss: 0.2407, Accuracy: 0.9060
# Combined Phase: Loss: 0.1732, Accuracy: 0.9293
# Train Loss: 0.2407, Train Accuracy: 0.9060
# Validation Loss: 0.1732, Validation Accuracy: 0.9293
# Validation accuracy improved from 0.0000 to 0.9293. Saving model.
# Epoch 1 completed in 19.07 seconds.
#
# Epoch 2/30 - Dataset: Combined
# Combined Phase: Loss: 0.1929, Accuracy: 0.9205
# Combined Phase: Loss: 0.1915, Accuracy: 0.9209
# Train Loss: 0.1929, Train Accuracy: 0.9205
# Validation Loss: 0.1915, Validation Accuracy: 0.9209
# Validation accuracy did not improve from 0.9293
# Epoch 2 completed in 18.50 seconds.
#
# Epoch 3/30 - Dataset: Combined
# Combined Phase: Loss: 0.1773, Accuracy: 0.9251
# Combined Phase: Loss: 0.1689, Accuracy: 0.9326
# Train Loss: 0.1773, Train Accuracy: 0.9251
# Validation Loss: 0.1689, Validation Accuracy: 0.9326
# Validation accuracy improved from 0.9293 to 0.9326. Saving model.
# Epoch 3 completed in 18.55 seconds.
#
# Epoch 4/30 - Dataset: Combined
# Combined Phase: Loss: 0.1701, Accuracy: 0.9347
# Combined Phase: Loss: 0.1520, Accuracy: 0.9405
# Train Loss: 0.1701, Train Accuracy: 0.9347
# Validation Loss: 0.1520, Validation Accuracy: 0.9405
# Validation accuracy improved from 0.9326 to 0.9405. Saving model.
# Epoch 4 completed in 18.57 seconds.
#
# Epoch 5/30 - Dataset: Combined
# Combined Phase: Loss: 0.1562, Accuracy: 0.9380
# Combined Phase: Loss: 0.1764, Accuracy: 0.9259
# Train Loss: 0.1562, Train Accuracy: 0.9380
# Validation Loss: 0.1764, Validation Accuracy: 0.9259
# Validation accuracy did not improve from 0.9405
# Epoch 5 completed in 18.97 seconds.
#
# Epoch 6/30 - Dataset: Combined
# Combined Phase: Loss: 0.1629, Accuracy: 0.9313
# Combined Phase: Loss: 0.1484, Accuracy: 0.9392
# Train Loss: 0.1629, Train Accuracy: 0.9313
# Validation Loss: 0.1484, Validation Accuracy: 0.9392
# Validation accuracy did not improve from 0.9405
# Epoch 6 completed in 18.80 seconds.
#
# Epoch 7/30 - Dataset: Combined
# Combined Phase: Loss: 0.1487, Accuracy: 0.9409
# Combined Phase: Loss: 0.1393, Accuracy: 0.9467
# Train Loss: 0.1487, Train Accuracy: 0.9409
# Validation Loss: 0.1393, Validation Accuracy: 0.9467
# Validation accuracy improved from 0.9405 to 0.9467. Saving model.
# Epoch 7 completed in 18.99 seconds.
#
# Epoch 8/30 - Dataset: Combined
# Combined Phase: Loss: 0.1345, Accuracy: 0.9530
# Combined Phase: Loss: 0.1198, Accuracy: 0.9546
# Train Loss: 0.1345, Train Accuracy: 0.9530
# Validation Loss: 0.1198, Validation Accuracy: 0.9546
# Validation accuracy improved from 0.9467 to 0.9546. Saving model.
# Epoch 8 completed in 18.57 seconds.
#
# Epoch 9/30 - Dataset: Combined
# Combined Phase: Loss: 0.1320, Accuracy: 0.9501
# Combined Phase: Loss: 0.1087, Accuracy: 0.9613
# Train Loss: 0.1320, Train Accuracy: 0.9501
# Validation Loss: 0.1087, Validation Accuracy: 0.9613
# Validation accuracy improved from 0.9546 to 0.9613. Saving model.
# Epoch 9 completed in 18.54 seconds.
#
# Epoch 10/30 - Dataset: Combined
# Combined Phase: Loss: 0.1209, Accuracy: 0.9576
# Combined Phase: Loss: 0.1078, Accuracy: 0.9617
# Train Loss: 0.1209, Train Accuracy: 0.9576
# Validation Loss: 0.1078, Validation Accuracy: 0.9617
# Validation accuracy improved from 0.9613 to 0.9617. Saving model.
# Epoch 10 completed in 18.55 seconds.
#
# Epoch 11/30 - Dataset: Combined
# Combined Phase: Loss: 0.1183, Accuracy: 0.9596
# Combined Phase: Loss: 0.1390, Accuracy: 0.9442
# Train Loss: 0.1183, Train Accuracy: 0.9596
# Validation Loss: 0.1390, Validation Accuracy: 0.9442
# Validation accuracy did not improve from 0.9617
# Epoch 11 completed in 18.48 seconds.
#
# Epoch 12/30 - Dataset: Combined
# Combined Phase: Loss: 0.1155, Accuracy: 0.9588
# Combined Phase: Loss: 0.1086, Accuracy: 0.9580
# Train Loss: 0.1155, Train Accuracy: 0.9588
# Validation Loss: 0.1086, Validation Accuracy: 0.9580
# Validation accuracy did not improve from 0.9617
# Epoch 12 completed in 18.46 seconds.
#
# Epoch 13/30 - Dataset: Combined
# Combined Phase: Loss: 0.1163, Accuracy: 0.9592
# Combined Phase: Loss: 0.1608, Accuracy: 0.9272
# Train Loss: 0.1163, Train Accuracy: 0.9592
# Validation Loss: 0.1608, Validation Accuracy: 0.9272
# Validation accuracy did not improve from 0.9617
# Epoch 13 completed in 18.50 seconds.
#
# Epoch 14/30 - Dataset: Combined
# Combined Phase: Loss: 0.1206, Accuracy: 0.9542
# Combined Phase: Loss: 0.1206, Accuracy: 0.9513
# Train Loss: 0.1206, Train Accuracy: 0.9542
# Validation Loss: 0.1206, Validation Accuracy: 0.9513
# Validation accuracy did not improve from 0.9617
# Epoch 14 completed in 18.48 seconds.
#
# Epoch 15/30 - Dataset: Combined
# Combined Phase: Loss: 0.1243, Accuracy: 0.9517
# Combined Phase: Loss: 0.1245, Accuracy: 0.9484
# Train Loss: 0.1243, Train Accuracy: 0.9517
# Validation Loss: 0.1245, Validation Accuracy: 0.9484
# Validation accuracy did not improve from 0.9617
# Early stopping triggered after 15 epochs.

# %%
# Training phase on Original Dataset
train_loss_original, train_accuracy_original = train_phase(
    train_loader=original_train_loader, 
    model=custom_model, 
    optimizer=optimizer, 
    criterion=criterion, 
    dataset_name="Original"
)

# Validation phase on Original Dataset
valid_loss_original, valid_accuracy_original = validation_phase(
    valid_loader=original_valid_loader, 
    model=custom_model, 
    criterion=criterion, 
    dataset_name="Original"
)

# Training phase on Combined Dataset
train_loss_combined, train_accuracy_combined = train_phase(
    train_loader=combined_train_loader, 
    model=custom_model, 
    optimizer=optimizer, 
    criterion=criterion, 
    dataset_name="Combined"
)

# Validation phase on Combined Dataset
valid_loss_combined, valid_accuracy_combined = validation_phase(
    valid_loader=combined_valid_loader, 
    model=custom_model, 
    criterion=criterion, 
    dataset_name="Combined"
)

# Test phase for Original Dataset
test_loss_original, test_acc_original = validation_phase(
    valid_loader=original_test_loader,
    model=custom_model,
    criterion=criterion,
    dataset_name="Original Test"
)

# Test phase for Combined Dataset
test_loss_combined, test_acc_combined = validation_phase(
    valid_loader=combined_test_loader,
    model=custom_model,
    criterion=criterion,
    dataset_name="Combined Test"
)

# Print the results
print(f"--- Original Dataset ---")
print(f"Training Loss: {train_loss_original:.4f}, Training Accuracy: {train_accuracy_original:.4f}")
print(f"Validation Loss: {valid_loss_original:.4f}, Validation Accuracy: {valid_accuracy_original:.4f}")
print(f"Test Loss: {test_loss_original:.4f}, Test Accuracy: {test_acc_original:.4f}")

print(f"\n--- Combined Dataset ---")
print(f"Training Loss: {train_loss_combined:.4f}, Training Accuracy: {train_accuracy_combined:.4f}")
print(f"Validation Loss: {valid_loss_combined:.4f}, Validation Accuracy: {valid_accuracy_combined:.4f}")
print(f"Test Loss: {test_loss_combined:.4f}, Test Accuracy: {test_acc_combined:.4f}")
# Out:
# Original Phase: Loss: 0.1680, Accuracy: 0.9384
# Original Phase: Loss: 0.1639, Accuracy: 0.9256
# Combined Phase: Loss: 0.1217, Accuracy: 0.9505
# Combined Phase: Loss: 0.1166, Accuracy: 0.9563
# Original Test Phase: Loss: 0.1834, Accuracy: 0.9219
# Combined Test Phase: Loss: 0.1166, Accuracy: 0.9563
# --- Original Dataset ---
# Training Loss: 0.1680, Training Accuracy: 0.9384
# Validation Loss: 0.1639, Validation Accuracy: 0.9256
# Test Loss: 0.1834, Test Accuracy: 0.9219
#
# --- Combined Dataset ---
# Training Loss: 0.1217, Training Accuracy: 0.9505
# Validation Loss: 0.1166, Validation Accuracy: 0.9563
# Test Loss: 0.1166, Test Accuracy: 0.9563

# %%
# Plot for original dataset
plt.figure(figsize=(12, 6))
plt.plot(original_train_loss_history, label="Original Training Loss", color='red')
plt.plot(original_valid_loss_history, label="Original Validation Loss", color='blue')
plt.plot(original_train_accuracy_history, label="Original Training Accuracy", color='green')
plt.plot(original_valid_accuracy_history, label="Original Validation Accuracy", color='orange')
plt.title("Original Dataset Metrics")
plt.xlabel("Epochs")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# Plot for combined dataset
plt.figure(figsize=(12, 6))
plt.plot(combined_train_loss_history, label="Combined Training Loss", color='red')
plt.plot(combined_valid_loss_history, label="Combined Validation Loss", color='blue')
plt.plot(combined_train_accuracy_history, label="Combined Training Accuracy", color='green')
plt.plot(combined_valid_accuracy_history, label="Combined Validation Accuracy", color='orange')
plt.title("Combined Dataset Metrics")
plt.xlabel("Epochs")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
test_acc_values = [test_acc_original, test_acc_combined]
test_loss_values = [test_loss_original, test_loss_combined]

datasets = ['Original Dataset', 'Combined Dataset']

x = np.arange(len(datasets))  
bar_width = 0.4  

fig, ax = plt.subplots(figsize=(10, 7))

bars1 = ax.bar(x - bar_width/2, test_acc_values, bar_width, label='Test Accuracy', color='skyblue')

bars2 = ax.bar(x + bar_width/2, test_loss_values, bar_width, label='Test Loss', color='salmon')

for bar, value in zip(bars1, test_acc_values):
    ax.text(
        bar.get_x() + bar.get_width() / 2, 
        bar.get_height() + 0.01,  
        f'{value * 100:.2f}',  
        ha='center', 
        va='bottom', 
        fontsize=10, 
        color='black'
    )

for bar, value in zip(bars2, test_loss_values):
    ax.text(
        bar.get_x() + bar.get_width() / 2, 
        bar.get_height() + 0.01, 
        f'{value:.2f}',  
        ha='center', 
        va='bottom', 
        fontsize=10, 
        color='black'
    )

ax.set_xlabel('Dataset')
ax.set_ylabel('Value')
ax.set_title('Comparison of Test Accuracy and Loss for DenseNet121')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()

plt.tight_layout()
plt.show()

# %%
print("Confusion Matrices:")
plot_confusion_matrices(true_1, preds_1, "Original", true_2, preds_2, "Combined")
# Out:
# Confusion Matrices:

# %%
print_metrics(true_1, preds_1, "Original", true_2, preds_2, "Combined")
# Out:
# Metrics for Original Dataset:
#               precision    recall  f1-score   support
#
#  Normal skin       0.97      0.79      0.87       359
#   Lumpy skin       0.90      0.99      0.94       729
#
#     accuracy                           0.92      1088
#    macro avg       0.94      0.89      0.91      1088
# weighted avg       0.93      0.92      0.92      1088
#
# Mean Squared Error (MSE): 0.0781
# Error Rate: 7.8125%
#
# Metrics for Combined Dataset:
#               precision    recall  f1-score   support
#
#  Normal skin       0.99      0.92      0.95      1143
#   Lumpy skin       0.93      0.99      0.96      1260
#
#     accuracy                           0.96      2403
#    macro avg       0.96      0.95      0.96      2403
# weighted avg       0.96      0.96      0.96      2403
#
# Mean Squared Error (MSE): 0.0437
# Error Rate: 4.3695%
